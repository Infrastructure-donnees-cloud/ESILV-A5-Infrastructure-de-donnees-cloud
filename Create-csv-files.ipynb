# %% [markdown]
# **Paramètres:**

# %%
# Configuration production
number_members = 10000
number_providers = 200
number_corporation = 500
number_loans = 50000

# Configuration dev
#number_members = 1000
#number_providers = 20
#number_corporation = 50
#number_loans = 500

# %% [markdown]
# **Dénormalisation retenue:**

# %%
{
    "members":
    {
        "member_no": "1",
        "lastname": "DOUGLAS",
        "firstname": "Michael",
        "phone_number":"blabla",
 
        "location":
        {
            "country":"France",
            "region_no":"IDF",
            "city":"Paris",
            "mail_code":"75000",
            "street":"blabla"
        },
 
        "balance":
        {
            "prev_balance": "1000",
            "curr_balance": "1200"
        },
 
        "_comment":"No need to have a list, each employee have only 1 corporation",
        "corporation":
        {
            "corp_no":1,
            "corp_name":"blabla",
            "region_no":"XX"
        },
 
        "charge": [
            {
                "charge_no": "125",
                "category_no": "12",
                "category_desc": "Travel",
                "charge_dt": "2000-02-22 10:43:38",
                "charge_amount": "336.0000",
 
                "provider_no":12,
                "provider_name":"BNP Paribas",
                "provider_phone_number": "blabla",
                "payments":[1546, 1547,... , 1578]
            }
        ]
},
     "providers":
        {
            "provider_no":1,
            "provider_name":"BNP",
            "location":
            {
                "country":"France",
                "region_no":"IDF",
                "city":"Paris",
                "mail_code":"75000"
            }
        },
 
 
    "payments":
        {
            "payment_no":1546,
            "payment_dt":"2000-02-22 10:43:38",
            "payment_amt":125.00
        }
}
# Out:
# {'members': {'member_no': '1',
#   'lastname': 'DOUGLAS',
#   'firstname': 'Michael',
#   'phone_number': 'blabla',
#   'location': {'country': 'France',
#    'region_no': 'IDF',
#    'city': 'Paris',
#    'mail_code': '75000',
#    'street': 'blabla'},
#   'balance': {'prev_balance': '1000', 'curr_balance': '1200'},
#   '_comment': 'No need to have a list, each employee have only 1 corporation',
#   'corporation': {'corp_no': 1, 'corp_name': 'blabla', 'region_no': 'XX'},
#   'charge': [{'charge_no': '125',
#     'category_no': '12',
#     'category_desc': 'Travel',
#     'charge_dt': '2000-02-22 10:43:38',
#     'charge_amount': '336.0000',
#     'provider_no': 12,
#     'provider_name': 'BNP Paribas',
#     'provider_phone_number': 'blabla',
#     'payments': [1546, 1547, Ellipsis, 1578]}]},
#  'providers': {'provider_no': 1,
#   'provider_name': 'BNP',
#   'location': {'country': 'France',
#    'region_no': 'IDF',
#    'city': 'Paris',
#    'mail_code': '75000'}},
#  'payments': {'payment_no': 1546,
#   'payment_dt': '2000-02-22 10:43:38',
#   'payment_amt': 125.0}}

# %%
Bank_list = [
    "Goldman Sachs",
    "Morgan Stanley",
    "Bank of America",
    "Citigroup",
    "JPMorgan Chase & Co",
    "Wells Fargo",
    "PNC Financial Services",
    "US Bank",
]

# %%
# !pip install random-address
# Out:
# Requirement already satisfied: random-address in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (1.1.1)

# %%
from faker import Faker
import pandas as pd
from random import randint, random, seed, randrange
import numpy as np
import math
seed(22) #random seed

from datetime import timedelta
from dateutil.relativedelta import relativedelta

from random_address import real_random_address

fake = Faker()

# %%
Members = pd.DataFrame([{
    "member_no": i,
    "lastname": fake.last_name_nonbinary(),
    "firstname": fake.first_name_nonbinary(),
    "phone_number": '0'+fake.msisdn()[3:] ,

    "country": "United States",
    "region_no": address['state'],
    "city": address['city'] if 'city' in address.keys() else 'Boston' ,
    "mail_code": address['postalCode'],
    "street": address['address1'],
    "corp_no": randint(0, number_corporation-1),
    
    "prev_balance": np.random.normal(1000, 500, 1)[0],
    "curr_balance": np.random.normal(1000, 500, 1)[0]
} for (i,address) in zip(range(number_members),[real_random_address() for i in range(number_members)]) ])
Members
# Out:
#       member_no lastname firstname phone_number        country region_no  \
# 0             0    Simon      Tina  03216756643  United States        AR
# 1             1     Hill      Gary  03167291118  United States        KY
# 2             2    Brown      John  01559209158  United States        CA
# 3             3  Goodman     James  07996340526  United States        FL
# 4             4  Johnson   Anthony  08501472892  United States        TN
# ...         ...      ...       ...          ...            ...       ...
# 9995       9995     Cruz    Denise  07537886427  United States        AL
# 9996       9996  Andrews      Anne  05179122505  United States        MD
# 9997       9997     Meza  Jonathan  02455503172  United States        FL
# 9998       9998   Romero    Deanna  05077988285  United States        AR
# 9999       9999   Foster    Brandi  08561950074  United States        MD
#
#               city mail_code                    street  corp_no  prev_balance  \
# 0     Fayetteville     72701       17 West 26th Circle       14    976.347914
# 1       Louisville     40211    1522 South 36th Street      284   1135.428302
# 2           Carson     90810  21950 Arnold Center Road      244    479.813406
# 3        Southport     32409         711 Tashanna Lane       53    767.177590
# 4        Nashville     37208          1816 14th Avenue        9    661.688533
# ...            ...       ...                       ...      ...           ...
# 9995    Montgomery     36106      4132 Carmichael Road      161    831.282595
# 9996   Glen Burnie     21061       309 Glenwood Avenue      420    999.271767
# 9997   Panama City     32405      105 Ridgecrest Court      249   1125.402364
# 9998  Fayetteville     72701        1653 Brooks Avenue      465    448.572370
# 9999         Deale     20733      1223 Delaware Avenue       52    446.476488
#
#       curr_balance
# 0       829.871762
# 1      1061.489794
# 2      1823.842763
# 3       532.289733
# 4       440.770944
# ...            ...
# 9995    859.460104
# 9996    173.466681
# 9997   1009.227479
# 9998   1150.847339
# 9999   1105.152644
#
# [10000 rows x 12 columns]

# %%
Members.to_csv('members.csv')

# %%
Providers = pd.DataFrame([{
    "provider_no": i,
    "provider_name": Bank_list[randint(0, len(Bank_list)-1)],
    "phone_number": '0'+fake.msisdn()[3:] ,
    "country": "United States",
    "region_no": address['state'],
    "city": address['city'] if 'city' in address.keys() else 'Boston' ,
    "mail_code": address['postalCode'],
    "street": address['address1'],
} for (i,address) in zip(range(number_providers),[real_random_address() for i in range(number_providers)]) ])
Providers
# Out:
#      provider_no           provider_name phone_number        country  \
# 0              0  PNC Financial Services  01888059400  United States
# 1              1             Wells Fargo  03467667694  United States
# 2              2  PNC Financial Services  00392540355  United States
# 3              3  PNC Financial Services  02353789903  United States
# 4              4          Morgan Stanley  01404081802  United States
# ..           ...                     ...          ...            ...
# 195          195               Citigroup  01796658013  United States
# 196          196     JPMorgan Chase & Co  01066394324  United States
# 197          197  PNC Financial Services  08444013282  United States
# 198          198  PNC Financial Services  02176699423  United States
# 199          199           Goldman Sachs  04121588199  United States
#
#     region_no               city mail_code                      street
# 0          CO             Arvada     80004          6473 Zephyr Street
# 1          VT             Boston     05733             8 Corona Street
# 2          CA      Mountain View     94040      2685 California Street
# 3          FL  Panama City Beach     32413      17878 Front Beach Road
# 4          MD          Annapolis     21401    992 Sherwood Forest Road
# ..        ...                ...       ...                         ...
# 195        CO             Arvada     80003            8467 Chase Drive
# 196        VT          Williston     05495     833 South Brownell Road
# 197        CO             Arvada     80003           7998 Chase Circle
# 198        OK      Oklahoma City     73159  3200 Southwest 95th Street
# 199        KY         Louisville     40223       244 La Normandy Drive
#
# [200 rows x 8 columns]

# %%
Providers.to_csv('providers.csv')

# %%
Corporations = pd.DataFrame([{
    "corp_no": i,
    "corp_name": fake.company(),
    "phone_number": '0'+fake.msisdn()[3:] ,
    "country": "United States",
    "region_no": address['state'],
    "city": address['city'] if 'city' in address.keys() else 'Boston' ,
    "mail_code": address['postalCode'],
    "street": address['address1']
} for (i,address) in zip(range(number_corporation),[real_random_address() for i in range(number_corporation)]) ])
Corporations
# Out:
#      corp_no                     corp_name phone_number        country  \
# 0          0       Collier, Kent and Henry  09766534610  United States
# 1          1     Ward, Mcbride and Salazar  05951501786  United States
# 2          2              Williams-Sampson  00556924957  United States
# 3          3     Richmond, Sharp and Stone  04637542202  United States
# 4          4                    Medina LLC  06362272814  United States
# ..       ...                           ...          ...            ...
# 495      495  Peterson, Mosley and Gregory  04120092001  United States
# 496      496               Nelson and Sons  05805460410  United States
# 497      497                   Jackson LLC  09088342033  United States
# 498      498                     Hall-Hill  01965685320  United States
# 499      499                   Krueger LLC  01990075392  United States
#
#     region_no           city mail_code                             street
# 0          AZ       Glendale     85301             7326 North 62nd Avenue
# 1          AL     Montgomery     36109               463 Pecan Tree Drive
# 2          CA  Castro Valley     94552  6145 East Castro Valley Boulevard
# 3          CA        Oakland     94609                    775 47th Street
# 4          AR   Fayetteville     72704             1649 Timberridge Court
# ..        ...            ...       ...                                ...
# 495        VT      Hyde Park     05655               54 Pine Meadow Drive
# 496        CT     Manchester     06040               14 Huntington Street
# 497        AZ       Glendale     85305             6605 North 93RD Avenue
# 498        GA       Savannah     31404                 2206 Skidaway Road
# 499        AR   Fayetteville     72703       4182 North Valley Lake Drive
#
# [500 rows x 8 columns]

# %%
credit_categories_list = ["School credit loan", "Real Estate loan", "Consumer loan"]
Categories = pd.DataFrame(credit_categories_list)
Categories['category_no'] = Categories.index
Categories.columns = ['category_name','category_no']
Categories
# Out:
#         category_name  category_no
# 0  School credit loan            0
# 1    Real Estate loan            1
# 2       Consumer loan            2

# %%
def get_school_loan():
    mu = 125000
    sigma = 1.2*mu
    x = int(np.random.normal(mu, sigma, 1)[0])
    return  x if x > 0 else mu

def get_real_estate_loan():
    mu = 500000
    sigma = 3*mu
    x = int(np.random.normal(mu, sigma, 1)[0])
    return  x if x > 0 else mu

def get_consummer_loan():
    mu = 5000
    sigma = 4*mu
    x = int(np.random.normal(mu, sigma, 1)[0])
    return  x if x > 0 else mu

def get_loan(category_no):
    
    loan_type = Categories[Categories['category_no']==category_no]['category_name'].values[0]
    if loan_type == "School credit loan":
        return get_school_loan()
    elif loan_type == "Real Estate loan":
        return get_real_estate_loan()
    else:
        return get_consummer_loan()

# %%
def random_date(start, end):
    delta = end - start
    random_days = randrange(delta.days)
    return start + timedelta(days=random_days)

from datetime import datetime
d1 = datetime.strptime('1/1/2020', '%m/%d/%Y')
d2 = datetime.strptime('1/1/2022', '%m/%d/%Y')
print(random_date(d1, d2))
# Out:
# 2020-05-31 00:00:00

# %%
loans = [[
    category_no, get_loan(category_no)
] for category_no in [randint(0, len(credit_categories_list)-1) for i in range(number_loans)]]
#loans

# %%
loans = pd.DataFrame(loans)
loans.columns = ['loan_type', 'loan_amuont']
loans
# Out:
#        loan_type  loan_amuont
# 0              1       500000
# 1              0        56532
# 2              0        38011
# 3              2         5000
# 4              1       500000
# ...          ...          ...
# 49995          1      1415590
# 49996          0       125000
# 49997          1      4663987
# 49998          2         5000
# 49999          0       187512
#
# [50000 rows x 2 columns]

# %%
charge_duration = [[i*12 for i in range(1,6)][randint(0, 4)] for j in range(len(loans))]

# %%
member_no = [randint(0, len(Members)-1) for i in range(len(loans))]

# %%
provider_no = [randint(0, len(Providers)-1) for i in range(len(loans))]

# %%
charge_dt = [random_date(d1, d2) for i in range(len(loans))]

# %%
Charges = pd.DataFrame([loans.loan_type.values, loans.loan_amuont.values, charge_duration, charge_dt, member_no, provider_no]).T
Charges.columns = ["Charge type", "Charge amount", "Duration", "dt", "member_no", "provider_no"]
Charges["charge_no"] = Charges.index
Charges
# Out:
#       Charge type Charge amount Duration         dt member_no provider_no  \
# 0               1        500000       24 2020-11-12      3020          73
# 1               0         56532       36 2021-07-03      4273          69
# 2               0         38011       48 2020-07-26      3992          42
# 3               2          5000       12 2020-09-11      9315           6
# 4               1        500000       60 2021-06-13      2008         188
# ...           ...           ...      ...        ...       ...         ...
# 49995           1       1415590       48 2021-01-01      7063          58
# 49996           0        125000       60 2021-07-30      3495          78
# 49997           1       4663987       48 2021-08-19      9286          86
# 49998           2          5000       60 2020-09-14      1859         143
# 49999           0        187512       60 2021-10-20      3846          44
#
#        charge_no
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 49995      49995
# 49996      49996
# 49997      49997
# 49998      49998
# 49999      49999
#
# [50000 rows x 7 columns]

# %% [markdown]
# **On considère que le dataset correspond à l'état des paiements des crédit en date du 1 octobre 2021.**
#
# **Par conséquent un emprûnt est en règle si tout les "statements" dont la due_dt est précédente au 1 octobre 2021 liés à cet umprunt ont été honorés.**

# %%
dt_1er_octobre_2021 = datetime(2020, 9, 1)
dt_1er_octobre_2021
# Out:
# datetime.datetime(2020, 9, 1, 0, 0)

# %%
def remboursera(row):
    if random() <= 0.98:
        return True
    else:
        return False


# In[17]:


def mois_de_defaut(row):
    if row['remboursera'] == False:
        moisDeDefaut = randint(0, row['Duration']-1)
        return moisDeDefaut
    else:
        return np.NaN

# %%
Charges['remboursera'] = Charges.apply(lambda row: remboursera(row), axis = 1)
Charges
# Out:
#       Charge type Charge amount Duration         dt member_no provider_no  \
# 0               1        500000       24 2020-11-12      3020          73
# 1               0         56532       36 2021-07-03      4273          69
# 2               0         38011       48 2020-07-26      3992          42
# 3               2          5000       12 2020-09-11      9315           6
# 4               1        500000       60 2021-06-13      2008         188
# ...           ...           ...      ...        ...       ...         ...
# 49995           1       1415590       48 2021-01-01      7063          58
# 49996           0        125000       60 2021-07-30      3495          78
# 49997           1       4663987       48 2021-08-19      9286          86
# 49998           2          5000       60 2020-09-14      1859         143
# 49999           0        187512       60 2021-10-20      3846          44
#
#        charge_no  remboursera
# 0              0         True
# 1              1         True
# 2              2         True
# 3              3         True
# 4              4         True
# ...          ...          ...
# 49995      49995         True
# 49996      49996         True
# 49997      49997         True
# 49998      49998         True
# 49999      49999         True
#
# [50000 rows x 8 columns]

# %%
Charges['Mois de défaut'] = Charges.apply(lambda row: mois_de_defaut(row), axis = 1)

# %%
t = [[
    [
        Charges["Charge amount"].iloc[i]/Charges["Duration"].iloc[i],
        Charges['dt'][i] + relativedelta(months=+j+1),
        j,
        Charges['charge_no'][i],
        Charges["member_no"][i]
    ] for j in range(Charges["Duration"][i])
] for i in range(len(Charges))]




Statements = pd.DataFrame([item for sublist in t for item in sublist])
Statements.columns = ["statement_amt","due_dt", "charge_statement_no","charge_no", "member_no"]
Statements["statement_no"] = Statements.index
Statements
# Out:
#          statement_amt     due_dt  charge_statement_no  charge_no  member_no  \
# 0         20833.333333 2020-12-12                    0          0       3020
# 1         20833.333333 2021-01-12                    1          0       3020
# 2         20833.333333 2021-02-12                    2          0       3020
# 3         20833.333333 2021-03-12                    3          0       3020
# 4         20833.333333 2021-04-12                    4          0       3020
# ...                ...        ...                  ...        ...        ...
# 1798555    3125.200000 2026-06-20                   55      49999       3846
# 1798556    3125.200000 2026-07-20                   56      49999       3846
# 1798557    3125.200000 2026-08-20                   57      49999       3846
# 1798558    3125.200000 2026-09-20                   58      49999       3846
# 1798559    3125.200000 2026-10-20                   59      49999       3846
#
#          statement_no
# 0                   0
# 1                   1
# 2                   2
# 3                   3
# 4                   4
# ...               ...
# 1798555       1798555
# 1798556       1798556
# 1798557       1798557
# 1798558       1798558
# 1798559       1798559
#
# [1798560 rows x 6 columns]

# %%
t = [[
    [
        Charges["Charge amount"].iloc[i]/Charges["Duration"].iloc[i],
        Charges['dt'][i] + relativedelta(months=+j+1),
        j,
        Charges['charge_no'][i],
        Charges["member_no"][i]
    ]
    for j in range(Charges["Duration"][i]) if (Charges['Mois de défaut'][i] != np.NaN) |(j < Charges['Mois de défaut'][i])
] for i in range(len(Charges))]

# %%
Payments = pd.DataFrame([item for sublist in t for item in sublist])
Payments.columns = ["payment_amt","due_dt", "charge_statement_no","charge_no", "member_no"]
Payments["payment_no"] = Payments.index
Payments
# Out:
#           payment_amt     due_dt  charge_statement_no  charge_no  member_no  \
# 0        20833.333333 2020-12-12                    0          0       3020
# 1        20833.333333 2021-01-12                    1          0       3020
# 2        20833.333333 2021-02-12                    2          0       3020
# 3        20833.333333 2021-03-12                    3          0       3020
# 4        20833.333333 2021-04-12                    4          0       3020
# ...               ...        ...                  ...        ...        ...
# 1798555   3125.200000 2026-06-20                   55      49999       3846
# 1798556   3125.200000 2026-07-20                   56      49999       3846
# 1798557   3125.200000 2026-08-20                   57      49999       3846
# 1798558   3125.200000 2026-09-20                   58      49999       3846
# 1798559   3125.200000 2026-10-20                   59      49999       3846
#
#          payment_no
# 0                 0
# 1                 1
# 2                 2
# 3                 3
# 4                 4
# ...             ...
# 1798555     1798555
# 1798556     1798556
# 1798557     1798557
# 1798558     1798558
# 1798559     1798559
#
# [1798560 rows x 6 columns]

# %%
Payments = Payments[Payments["due_dt"] < dt_1er_octobre_2021]
Payments
# Out:
#           payment_amt     due_dt  charge_statement_no  charge_no  member_no  \
# 60         791.895833 2020-08-26                    0          2       3992
# 192      21373.104167 2020-08-15                    0          6       4765
# 276       2083.333333 2020-08-10                    0          8       2095
# 552        138.888889 2020-04-30                    0         15       5867
# 553        138.888889 2020-05-30                    1         15       5867
# ...               ...        ...                  ...        ...        ...
# 1798104   1701.312500 2020-08-28                    0      49990       4431
# 1798212    416.666667 2020-05-17                    0      49993       9351
# 1798213    416.666667 2020-06-17                    1      49993       9351
# 1798214    416.666667 2020-07-17                    2      49993       9351
# 1798215    416.666667 2020-08-17                    3      49993       9351
#
#          payment_no
# 60               60
# 192             192
# 276             276
# 552             552
# 553             553
# ...             ...
# 1798104     1798104
# 1798212     1798212
# 1798213     1798213
# 1798214     1798214
# 1798215     1798215
#
# [57621 rows x 6 columns]

# %%
Charges.remboursera.value_counts(normalize=True)
# Out:
# True     0.97908
# False    0.02092
# Name: remboursera, dtype: float64

# %%
Charges.drop(["remboursera","Mois de défaut"], axis=1, inplace=True)
Statements = Statements.drop(["charge_statement_no"], axis=1)
Payments = Payments.drop(["charge_statement_no"], axis=1)

# %%
Members
# Out:
#       member_no lastname firstname phone_number        country region_no  \
# 0             0    Simon      Tina  03216756643  United States        AR
# 1             1     Hill      Gary  03167291118  United States        KY
# 2             2    Brown      John  01559209158  United States        CA
# 3             3  Goodman     James  07996340526  United States        FL
# 4             4  Johnson   Anthony  08501472892  United States        TN
# ...         ...      ...       ...          ...            ...       ...
# 9995       9995     Cruz    Denise  07537886427  United States        AL
# 9996       9996  Andrews      Anne  05179122505  United States        MD
# 9997       9997     Meza  Jonathan  02455503172  United States        FL
# 9998       9998   Romero    Deanna  05077988285  United States        AR
# 9999       9999   Foster    Brandi  08561950074  United States        MD
#
#               city mail_code                    street  corp_no  prev_balance  \
# 0     Fayetteville     72701       17 West 26th Circle       14    976.347914
# 1       Louisville     40211    1522 South 36th Street      284   1135.428302
# 2           Carson     90810  21950 Arnold Center Road      244    479.813406
# 3        Southport     32409         711 Tashanna Lane       53    767.177590
# 4        Nashville     37208          1816 14th Avenue        9    661.688533
# ...            ...       ...                       ...      ...           ...
# 9995    Montgomery     36106      4132 Carmichael Road      161    831.282595
# 9996   Glen Burnie     21061       309 Glenwood Avenue      420    999.271767
# 9997   Panama City     32405      105 Ridgecrest Court      249   1125.402364
# 9998  Fayetteville     72701        1653 Brooks Avenue      465    448.572370
# 9999         Deale     20733      1223 Delaware Avenue       52    446.476488
#
#       curr_balance
# 0       829.871762
# 1      1061.489794
# 2      1823.842763
# 3       532.289733
# 4       440.770944
# ...            ...
# 9995    859.460104
# 9996    173.466681
# 9997   1009.227479
# 9998   1150.847339
# 9999   1105.152644
#
# [10000 rows x 12 columns]

# %%
Corporations
# Out:
#      corp_no                     corp_name phone_number        country  \
# 0          0       Collier, Kent and Henry  09766534610  United States
# 1          1     Ward, Mcbride and Salazar  05951501786  United States
# 2          2              Williams-Sampson  00556924957  United States
# 3          3     Richmond, Sharp and Stone  04637542202  United States
# 4          4                    Medina LLC  06362272814  United States
# ..       ...                           ...          ...            ...
# 495      495  Peterson, Mosley and Gregory  04120092001  United States
# 496      496               Nelson and Sons  05805460410  United States
# 497      497                   Jackson LLC  09088342033  United States
# 498      498                     Hall-Hill  01965685320  United States
# 499      499                   Krueger LLC  01990075392  United States
#
#     region_no           city mail_code                             street
# 0          AZ       Glendale     85301             7326 North 62nd Avenue
# 1          AL     Montgomery     36109               463 Pecan Tree Drive
# 2          CA  Castro Valley     94552  6145 East Castro Valley Boulevard
# 3          CA        Oakland     94609                    775 47th Street
# 4          AR   Fayetteville     72704             1649 Timberridge Court
# ..        ...            ...       ...                                ...
# 495        VT      Hyde Park     05655               54 Pine Meadow Drive
# 496        CT     Manchester     06040               14 Huntington Street
# 497        AZ       Glendale     85305             6605 North 93RD Avenue
# 498        GA       Savannah     31404                 2206 Skidaway Road
# 499        AR   Fayetteville     72703       4182 North Valley Lake Drive
#
# [500 rows x 8 columns]

# %%
Providers
# Out:
#      provider_no           provider_name phone_number        country  \
# 0              0  PNC Financial Services  01888059400  United States
# 1              1             Wells Fargo  03467667694  United States
# 2              2  PNC Financial Services  00392540355  United States
# 3              3  PNC Financial Services  02353789903  United States
# 4              4          Morgan Stanley  01404081802  United States
# ..           ...                     ...          ...            ...
# 195          195               Citigroup  01796658013  United States
# 196          196     JPMorgan Chase & Co  01066394324  United States
# 197          197  PNC Financial Services  08444013282  United States
# 198          198  PNC Financial Services  02176699423  United States
# 199          199           Goldman Sachs  04121588199  United States
#
#     region_no               city mail_code                      street
# 0          CO             Arvada     80004          6473 Zephyr Street
# 1          VT             Boston     05733             8 Corona Street
# 2          CA      Mountain View     94040      2685 California Street
# 3          FL  Panama City Beach     32413      17878 Front Beach Road
# 4          MD          Annapolis     21401    992 Sherwood Forest Road
# ..        ...                ...       ...                         ...
# 195        CO             Arvada     80003            8467 Chase Drive
# 196        VT          Williston     05495     833 South Brownell Road
# 197        CO             Arvada     80003           7998 Chase Circle
# 198        OK      Oklahoma City     73159  3200 Southwest 95th Street
# 199        KY         Louisville     40223       244 La Normandy Drive
#
# [200 rows x 8 columns]

# %%
Charges
# Out:
#       Charge type Charge amount Duration         dt member_no provider_no  \
# 0               1        500000       24 2020-11-12      3020          73
# 1               0         56532       36 2021-07-03      4273          69
# 2               0         38011       48 2020-07-26      3992          42
# 3               2          5000       12 2020-09-11      9315           6
# 4               1        500000       60 2021-06-13      2008         188
# ...           ...           ...      ...        ...       ...         ...
# 49995           1       1415590       48 2021-01-01      7063          58
# 49996           0        125000       60 2021-07-30      3495          78
# 49997           1       4663987       48 2021-08-19      9286          86
# 49998           2          5000       60 2020-09-14      1859         143
# 49999           0        187512       60 2021-10-20      3846          44
#
#        charge_no
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 49995      49995
# 49996      49996
# 49997      49997
# 49998      49998
# 49999      49999
#
# [50000 rows x 7 columns]

# %%
Categories
# Out:
#         category_name  category_no
# 0  School credit loan            0
# 1    Real Estate loan            1
# 2       Consumer loan            2

# %%
Statements
# Out:
#          statement_amt     due_dt  charge_no  member_no  statement_no
# 0         20833.333333 2020-12-12          0       3020             0
# 1         20833.333333 2021-01-12          0       3020             1
# 2         20833.333333 2021-02-12          0       3020             2
# 3         20833.333333 2021-03-12          0       3020             3
# 4         20833.333333 2021-04-12          0       3020             4
# ...                ...        ...        ...        ...           ...
# 1798555    3125.200000 2026-06-20      49999       3846       1798555
# 1798556    3125.200000 2026-07-20      49999       3846       1798556
# 1798557    3125.200000 2026-08-20      49999       3846       1798557
# 1798558    3125.200000 2026-09-20      49999       3846       1798558
# 1798559    3125.200000 2026-10-20      49999       3846       1798559
#
# [1798560 rows x 5 columns]

# %%
Payments
# Out:
#           payment_amt     due_dt  charge_no  member_no  payment_no
# 60         791.895833 2020-08-26          2       3992          60
# 192      21373.104167 2020-08-15          6       4765         192
# 276       2083.333333 2020-08-10          8       2095         276
# 552        138.888889 2020-04-30         15       5867         552
# 553        138.888889 2020-05-30         15       5867         553
# ...               ...        ...        ...        ...         ...
# 1798104   1701.312500 2020-08-28      49990       4431     1798104
# 1798212    416.666667 2020-05-17      49993       9351     1798212
# 1798213    416.666667 2020-06-17      49993       9351     1798213
# 1798214    416.666667 2020-07-17      49993       9351     1798214
# 1798215    416.666667 2020-08-17      49993       9351     1798215
#
# [57621 rows x 5 columns]

# %%
def export_csv():
    Members.to_csv('Members.csv', index=False)
    Corporations.to_csv('Corporations.csv', index=False)
    Categories.to_csv('Categories.csv', index=False)
    Providers.to_csv('Prodivers.csv', index=False)
    Charges.to_csv('Charges.csv', index=False)
    Statements.to_csv('Statements.csv', index=False)
    Payments.to_csv('Payments.csv', index=False)

# %%
export_csv()
